# %%
# %%
# --- STEP 1: GLOBAL CONFIGURATION & IMPORTS ---
import pandas as pd
import numpy as np
import os
import sys
import glob

# 1. PATH CONFIGURATION
# Adjust 'DATA_DIR' if your notebook is not in 'notebooks/'
DATA_DIR = os.path.join("..", "data", "raw") 
SRC_DIR = os.path.join("..", "src")

# 2. DOWNLOAD CHECK (Optional)
# If raw files are missing, we attempt to run your existing download script.
# Set DOWNLOAD_MISSING = False to skip this check entirely.
DOWNLOAD_MISSING = True

def check_and_download():
    # We now only need the ACS PUMS Person (p) and Housing (h) files
    required_patterns = [
        "psam_p*.csv", # Person Data
        "psam_h*.csv"  # Housing Data
    ]
    
    missing = False
    for pattern in required_patterns:
        # If glob doesn't find any files matching the pattern, mark as missing
        if not glob.glob(os.path.join(DATA_DIR, pattern)):
            missing = True
            break
    
    if missing and DOWNLOAD_MISSING:
        print("⚠️ Missing PUMS files (Person or Housing). Attempting download...")
        sys.path.append(os.path.abspath(SRC_DIR))
        try:
            import download_acs
            # Trigger the download for the PUMS files
            download_acs.download_acs_data()
            print("✅ Download complete.")
        except ImportError:
            print("❌ Could not import 'download_acs.py' from '../src'. Please check paths.")
        except Exception as e:
            print(f"❌ Download failed: {e}")
    elif not missing:
        print("✅ All required PUMS raw files are present.")

check_and_download()
# Out:
# ⚠️ Missing PUMS files (Person or Housing). Attempting download...
# Saving data to: /Users/zhenyuyue/Erdos/spring-2026-local-poverty-rate-estimation/src/../data/raw
#
# Target Region: ['MD', 'DC', 'VA']
# Fetching file list from Census Bureau...
# Found 12 files to download.
# [1/12] Downloading csv_hdc.zip... Done.
# [2/12] Downloading csv_hmd.zip... Done.
# [3/12] Downloading csv_hva.zip... Done.
# [4/12] Downloading csv_pdc.zip... Done.
# [5/12] Downloading csv_pmd.zip... Done.
# [6/12] Downloading csv_pva.zip... Done.
# [7/12] Downloading sas_hdc.zip... Done.
# [8/12] Downloading sas_hmd.zip... Done.
# [9/12] Downloading sas_hva.zip... Done.
# [10/12] Downloading sas_pdc.zip... Done.
# [11/12] Downloading sas_pmd.zip... Done.
# [12/12] Downloading sas_pva.zip... Done.
#
# Success! All files extracted to: /Users/zhenyuyue/Erdos/spring-2026-local-poverty-rate-estimation/src/../data/raw
# ✅ Download complete.

# %%
# %%
import pandas as pd
import glob
import os

# --- PATH CONFIGURATION ---
DATA_RAW = os.path.join("..", "data", "raw")

# 1. CORRECTED COLUMN LISTS
# Removed POVPIP, renamed ACCESS to ACCESSINET
household_cols = ['SERIALNO', 'FS', 'FFSP', 'ACCESSINET', 'VEH']
# Added POVPIP here
person_cols = ['SERIALNO', 'POVPIP', 'AGEP', 'SCHL', 'DIS', 'HISP', 'RAC1P', 'ESR']

print("🚀 Loading and Merging PUMS Microdata...")

# --- 2. LOAD HOUSEHOLD DATA ---
h_files = glob.glob(os.path.join(DATA_RAW, "psam_h*.csv"))
if h_files:
    # Read all matching files and combine them
    df_h_raw = pd.concat([pd.read_csv(f, usecols=household_cols) for f in h_files], ignore_index=True)
    print(f"   ✅ Household Data Loaded: {df_h_raw.shape}")
else:
    print("   ❌ Missing: psam_h*.csv files in data/raw")

# --- 3. LOAD PERSON DATA ---
p_files = glob.glob(os.path.join(DATA_RAW, "psam_p*.csv"))
if p_files:
    df_p_raw = pd.concat([pd.read_csv(f, usecols=person_cols) for f in p_files], ignore_index=True)
    print(f"   ✅ Person Data Loaded: {df_p_raw.shape}")
else:
    print("   ❌ Missing: psam_p*.csv files in data/raw")

# --- 4. FILTER AND MERGE ---
if h_files and p_files:
    print("\n⚙️ Processing and merging datasets...")
    
    # Create the Target Variable on Household data (1 = In the Gap, 0 = Has SNAP)
    df_h_raw['SNAP_GAP'] = df_h_raw['FS'].apply(lambda x: 1 if x == 2 else 0)
    
    # Filter out imputed SNAP values (FFSP == 1) to ensure ground-truth data
    df_h_clean = df_h_raw[df_h_raw['FFSP'] != 1].copy()
    
    # Inner join Person and Household on SERIALNO
    df_flat = pd.merge(df_p_raw, df_h_clean, on='SERIALNO', how='inner')
    
    # NOW we filter for the eligible population using POVPIP (which came from the person file)
    # We keep rows where the poverty ratio is <= 130
    df_flat_eligible = df_flat[df_flat['POVPIP'] <= 130].copy()
    
    print(f"   ✅ Flat Data Ready! Total people in eligible households: {df_flat_eligible.shape[0]}")
    
    # Display the first few rows
    display(df_flat_eligible.head())
# Out:
# 🚀 Loading and Merging PUMS Microdata...
#    ✅ Household Data Loaded: (74024, 5)
#    ✅ Person Data Loaded: (157694, 8)
#
# ⚙️ Processing and merging datasets...
#    ✅ Flat Data Ready! Total people in eligible households: 17172
#          SERIALNO  AGEP  SCHL  DIS  ESR  HISP  POVPIP  RAC1P  ACCESSINET   FS  \
# 3   2023GQ0002296    55  18.0    2  6.0     1    58.0      2         NaN  2.0
# 28  2023GQ0014288    56  16.0    2  6.0     1    64.0      2         NaN  1.0
# 30  2023GQ0014652    27  22.0    2  6.0     1     0.0      1         NaN  2.0
# 38  2023GQ0017494    59   1.0    2  6.0     1     0.0      2         NaN  2.0
# 73  2023GQ0032266    41  17.0    2  1.0     1    59.0      2         NaN  1.0
#
#     VEH  FFSP  SNAP_GAP
# 3   NaN     0         1
# 28  NaN     0         0
# 30  NaN     0         1
# 38  NaN     0         1
# 73  NaN     0         0
